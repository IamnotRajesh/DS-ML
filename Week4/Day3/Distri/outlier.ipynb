# %%
import pandas as pd

# %%
dataset = pd.read_csv('healthanxiety_dataset.csv')
dataset.head()
# Out:
#        subreddit           author      date  \
# 0  healthanxiety         Nomis176  1/1/2018
# 1  healthanxiety  psychstudent317  1/1/2018
# 2  healthanxiety        bulk_barn  1/1/2018
# 3  healthanxiety    AutoModerator  1/1/2018
# 4  healthanxiety    parthkhurana7  1/1/2018
#
#                                                 post  \
# 0  Final doctor appointment tomorrow, tired of co...
# 1  Anyone have bone or muscle pain that was stres...
# 2  Listening to your body? I'm curious how those ...
# 3  Weekly /r/HealthAnxiety Challenge - Exercise A...
# 4  This is killing me So i had a bacterial stomac...
#
#    automated_readability_index  coleman_liau_index  \
# 0                     9.137909            7.282428
# 1                     4.399892            7.131386
# 2                     3.590660            4.930895
# 3                     4.515682            7.033342
# 4                     3.034388            5.356252
#
# ...

# %%
new_dataset = dataset.sample(30)
new_dataset.head()
# Out:
#           subreddit             author       date  \
# 1213  healthanxiety               emyi   2/5/2019
# 1525  healthanxiety    SpicyCrabsushi1   3/7/2019
# 1429  healthanxiety             ppptub  2/25/2019
# 1029  healthanxiety  georgejefferson11  1/19/2019
# 499   healthanxiety       Footpainhelp   3/8/2018
#
#                                                    post  \
# 1213  Abdominal aorta anxiety I can strongly feel my...
# 1525  Kidney disease/damage? Freaking out a little r...
# 1429  Freaking out over HIV So a little over a year ...
# 1029  Body extremely heavy, and so much more :( My b...
# 499   Really scared of diabetes I am a major hypocho...
#
#       automated_readability_index  coleman_liau_index  \
# 1213                     1.154000            3.191912
# 1525                     2.105641            4.756979
# 1429                     1.856618            3.891243
# 1029                     2.858361            5.274282
# ...
